# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviVerma-75/language/blob/main/speachtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#upload the project prompt google colab to github
#crete speak to text converter application
#crete audio to text using whisper model and upload the code to github
